# %%
import json


armor_img_path = 'gear/armor/<sub_type> (<num>)'
weapon_img_path = 'gear/weapons/<sub_type> (<num>)'

buy_price_multiplier = 1.75

final_dict = {}

#atk_stab, atk_slash, atk_crush
main_stats = {
    'sword': 'atk_slash',
    'dagger': 'atk_stab',
    'axe': 'atk_slash',
    'gauntlet': 'atk_stab',
    'knuckles': 'atk_crush',
    'maul': 'atk_crush',
    'spear': 'atk_stab'
}

region_materials = {
    1: 'Stone',
    2: 'Bloodstone',
    3: 'Soulstone',
    4: 'Dulite',
    5: 'Midite',
    6: 'Shinite',
    7: 'Desite',
    8: 'Lavite',
    9: 'Bonite',
    10: 'Twisted'
}

armor_item_type_to_column = {
    'helmet': 5,
    'chestplate': 7,
    'gloves': 3,
    'boots': 1
}

#First index will be normal price, second will be the exotic price
weapon_item_type_to_column = {
    'sword': [2, 10],
    'dagger': [0, 10],
    'axe': [8, 13],
    'gauntlet': [4, 11],
    'knuckles': [4, 11],
    'maul': [9, 13],
    'spear': [6, 12]
}

#Grab this right from google sheets so it includes the tabs
sell_prices = """
48	65	99	122	169	198	259	295	372	412	507	556	670	729
132	184	261	325	426	505	636	728	886	997	1179	1312	1529	1689
297	408	562	689	877	1036	1256	1429	1690	1891	2200	2433	2799	3069
536	732	978	1204	1500	1762	2117	2386	2802	3102	3589	3925	4492	4870
850	1167	1529	1892	2313	2728	3216	3633	4185	4726	5362	5880	6597	7170
1254	1700	2220	2759	3364	3916	4603	5213	5992	6668	7399	8131	9105	9918
1760	2393	3120	3745	4558	5317	6243	7087	7962	8879	10044	10816	12102	13216
2355	3140	4091	5021	5972	6984	8197	9108	10456	11691	12898	14247	15540	17012
2990	4083	5323	6388	7775	8886	10434	11593	13315	14525	16438	17702	19823	21144
3769	5161	6552	8081	9573	11253	12853	14701	16413	17905	20281	21841	24483	26115
"""

armor_data = """
helmet	1	Cloth Helmet	1	188	188	188
chestplate	1	Cloth Chestplate	1	235	235	235
gloves	1	Cloth Gloves	1	141	141	141
boots	1	Cloth Boots	1	94	94	94
helmet	2	Leather Helmet	2	257	257	257
chestplate	2	Leather Chestplate	2	321	321	321
gloves	2	Leather Gloves	2	192	192	192
boots	2	Leather Boots	2	128	128	128
helmet	3	Hardleather Helmet	3	360	360	360
chestplate	3	Hardleather Chestplate	3	450	450	450
gloves	3	Hardleather Gloves	3	270	270	270
boots	3	Hardleather Boots	3	180	180	180
helmet	4	Dulite Helmet	4	428	428	428
chestplate	4	Dulite Chestplate	4	535	535	535
gloves	4	Dulite Gloves	4	321	321	321
boots	4	Dulite Boots	4	214	214	214
helmet	5	Midite Helmet	5	565	565	565
chestplate	5	Midite Chestplate	5	707	707	707
gloves	5	Midite Gloves	5	424	424	424
boots	5	Midite Boots	5	282	282	282
helmet	6	Shinite Helmet	6	771	771	771
chestplate	6	Shinite Chestplate	6	964	964	964
knuckles	2	Subtle Sting	17	1.9	13	45	0	0	956
knuckles	3	Soulstone Knuckles	8	1.8	12	42	0	0	1109
knuckles	3	The Pounders	22	1.9	13	45	0	0	1339
knuckles	4	Dulite Knuckles	2	2.1	38	127	0	0	1445
knuckles	4	Winters Bite	15	1.9	34	115	0	0	1594
knuckles	5	Midite Knuckles	3	1.7	30	103	0	0	1809
knuckles	5	Dualism	14	2.1	38	127	0	0	2104
knuckles	6	Shinite Knuckles	4	2	36	121	0	0	2498
knuckles	6	Dual Knuckles	24	2	36	121	0	0	2869
knuckles	7	Desite Knuckles	5	1.9	96	335	0	0	2997
knuckles	7	Elecdesite Knuckles	9	2	101	353	0	0	3132
knuckles	7	Facial Makeover	13	2.1	106	371	0	0	3379
knuckles	8	Lavite Knuckles	6	1.7	86	300	0	0	3553
knuckles	8	Blazite Knuckles	10	2.1	106	371	0	0	3898
knuckles	8	Flesh Leech	20	1.8	91	318	0	0	4399
knuckles	9	Bonite Knuckles	7	2.1	106	371	0	0	4819
knuckles	9	Life Eater	21	2.1	106	371	0	0	5466
knuckles	9	Eye Bruisers	16	1.9	96	335	0	0	5929
knuckles	10	Twisted Knuckles	12	2.1	289	1013	0	0	5998
knuckles	10	Life Voider	23	1.9	262	917	0	0	6045
knuckles	10	Nullfists	19	2.1	289	1013	0	0	6089
"""

#===================
# Weapons
#===================
for row in weapon_data.split('\n'):
    arr = row.split('\t')

    if len(arr) <= 1:
        continue

    sub_type = arr[0]
    region = int(arr[1])
    name = arr[2]
    img = int(arr[3])
    atk_speed = arr[4]
    min_hit = arr[5]
    max_hit = arr[6]
    atk_stab = arr[7]
    atk_slash = arr[8]
    atk_crush = arr[9]

    #Get the id from the display name
    item_id = name.replace(' ', '_')
    item_id = item_id.lower()
    
    final_dict[item_id] = {}
    
    final_dict[item_id]["name"] = name
    final_dict[item_id]["img_path"] = weapon_img_path.replace('<num>', str(img)).replace('<sub_type>', sub_type)
    
    desc = ''
    
    if '_' + sub_type in item_id:
        if sub_type == 'knuckles':
            desc = sub_type.capitalize() + ' made from ' + item_id.replace('_' + sub_type, '')
        elif sub_type == 'axe':
            desc = 'An axe made from ' + item_id.replace('_axe', '')
        else:
            desc = 'A ' + sub_type + ' made from ' + item_id.replace('_' + sub_type, '')
    
    final_dict[item_id]["desc"] = desc
    final_dict[item_id]["main_stat"] = main_stats[sub_type]
    final_dict[item_id]["type"] = 'weapon'
    
    #Find buy and sell price based on material, region, and sub type
    region_material = region_materials[region]
    price_index = -1
    
    if region_material in name[0:len(region_material)]:
        price_index = weapon_item_type_to_column[sub_type][0]
    else:
        price_index = weapon_item_type_to_column[sub_type][1]
    
    sell_price = int(sell_prices.split('\n')[region].split('\t')[price_index])
    buy_price = round(sell_price * buy_price_multiplier)
    
    final_dict[item_id]["buy_price"] = str(buy_price)
    final_dict[item_id]["sell_price"] = str(sell_price)
    
    final_dict[item_id]["abilities"] = {}
    
    final_dict[item_id]["atk_speed"] = atk_speed
    final_dict[item_id]["atk_crush"] = atk_crush
    final_dict[item_id]["atk_slash"] = atk_slash
    final_dict[item_id]["atk_stab"] = atk_stab
    final_dict[item_id]["max_hit"] = max_hit
    final_dict[item_id]["min_hit"] = min_hit

    
#===================
# Armor
#===================
for row in armor_data.split('\n'):
    arr = row.split('\t')

    if len(arr) <= 1:
        continue

    sub_type = arr[0]
    region = int(arr[1])
    name = arr[2]
    img = int(arr[3])
    def_stab = int(arr[4])
    def_crush = int(arr[5])
    def_slash = int(arr[6])

    #Get the id from the display name
    item_id = name.replace(' ', '_')
    item_id = item_id.lower()

    final_dict[item_id] = {}

    final_dict[item_id]["name"] = name
    final_dict[item_id]["img_path"] = armor_img_path.replace('<num>', str(img)).replace('<sub_type>', sub_type)

    if sub_type in ['helmet', 'chestplate']:
        desc = "A " + sub_type + " made from " + item_id.replace('_' + sub_type, '')
    else:
        desc = sub_type.capitalize() + " made from " + item_id.replace('_' + sub_type, '')

    final_dict[item_id]["desc"] = desc
    final_dict[item_id]["type"] = 'armor'
    final_dict[item_id]["sub_type"] = sub_type

    #Find buy and sell price based on material, region, and sub type
    price_index = armor_item_type_to_column[sub_type]

    sell_price = int(sell_prices.split('\n')[region].split('\t')[price_index])
    buy_price = round(sell_price * buy_price_multiplier)
    
    final_dict[item_id]["buy_price"] = str(buy_price)
    final_dict[item_id]["sell_price"] = str(sell_price)

    final_dict[item_id]["abilities"] = {}

    final_dict[item_id]["def_stab"] = def_stab
    final_dict[item_id]["def_crush"] = def_crush
    final_dict[item_id]["def_slash"] = def_slash
    final_dict[item_id]["health"] = "0"
    final_dict[item_id]["dmg_reduc"] = "0"
    
    
print(json.dumps(final_dict))
# Out:
# {"stone_sword": {"name": "Stone Sword", "img_path": "gear/weapons/sword (1)", "desc": "A sword made from stone", "main_stat": "atk_slash", "type": "weapon", "buy_price": "173", "sell_price": "99", "abilities": {}, "atk_speed": "2.5", "atk_crush": "0", "atk_slash": "532", "atk_stab": "0", "max_hit": "78", "min_hit": "25"}, "the_ripper": {"name": "The Ripper", "img_path": "gear/weapons/sword (16)", "desc": "", "main_stat": "atk_slash", "type": "weapon", "buy_price": "887", "sell_price": "507", "abilities": {}, "atk_speed": "2.3", "atk_crush": "0", "atk_slash": "575", "atk_stab": "0", "max_hit": "72", "min_hit": "23"}, "cell_splitter": {"name": "Cell Splitter", "img_path": "gear/weapons/sword (22)", "desc": "", "main_stat": "atk_slash", "type": "weapon", "buy_price": "887", "sell_price": "507", "abilities": {}, "atk_speed": "2.2", "atk_crush": "0", "atk_slash": "617", "atk_stab": "0", "max_hit": "70", "min_hit": "22"}, "bloodstone_sword": {"name": "Bloodstone Sword", "img_path": "gear/w
# ...
