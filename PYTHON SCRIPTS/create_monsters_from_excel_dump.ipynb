# %%
#Grab this right from google sheets so it includes the tabs

region_keys = {
    '1': 'verdant_valley',
    '2': 'fatal_forest',
    '3': 'gruesome_grove',
    '4': 'dangerous_depths',
    '5': 'wretched_wasteland',
    '6': 'gory_graveyard',
    '7': 'satanic_swamp',
    '8': 'perilous_peaks',
    '9': 'menacing_mountain',
    '10': 'vicious_void',
}

final_dict = {}

data = """
1	Farm Chicken	valley_chicken
1	Sneaky Rabbit	valley_rabbit
1	Crusty Crab	valley_crab
1	Feral Rat	valley_cat
1	Noisy Goat	valley_goat
1	Earth Elemental	valley_elemental
1	Squishy Slime	valley_slime
1	Nagenie	valley_snake
2	Jungle Bullfrog	forest_frog
2	Grimy Gecko	forest_gecko
2	Dwarf Warrior	forest_dwarf
2	Tree Slime	forest_slime
2	Treeshroom	forest_mushroom
2	Earth Totem	forest_totem
2	Poisonous Skull	forest_skull
2	Kuhthooloo	forest_eye
3	Wild Longbeak	grove_longbeak
3	Gassy Ghast	grove_ghast
3	Grove Turret	grove_sentry
3	Fleshy Lump	grove_head
3	Grove Guardian	grove_golem
3	Dark Ghast	grove_mist
3	Flaming Cranium	grove_skull
3	Hunuh Abit	grove_witch
4	Dark Elemental	depths_elemental
4	Shadow Slime	depths_slime
4	Watchful Eye	depths_eye
4	Living Tomb	depths_tombstone
4	Mimic	depths_chest
4	Haunted Skull	depths_skull
4	Sentry Golem	depths_golem
4	Doolism	depths_shield
5	Sand Walker	wasteland_mummy
5	Water Pumper	wasteland_robot
5	Pyramidian	wasteland_pyramidian
5	Flesh Snatcher	wasteland_snake
5	Dustnado	wasteland_dustnado
5	Scorpio	wasteland_scorpion
5	Sand Digger	wasteland_lurker
5	Long Lost Spirit	wasteland_mask
6	Feral Bat	graveyard_bat
6	Death Rat	graveyard_cat
6	Kindred Spirit	graveyard_ghast
6	Starved Zombie	graveyard_zombie
6	Arcane Bones	graveyard_skeleton
6	Flesh Eater	graveyard_flesh_eater
6	Kont Drukola	graveyard_count_dracula
6	Grem Ripper	graveyard_reaper
7	Confused Moth	swamp_moth
7	Curshroom	swamp_mushroom
7	Viscous Sludge	swamp_head
7	Brain Floater	swamp_brain
7	Sacred Spirit	swamp_mask
7	Dream Catcher	swamp_eye
7	Dying Crone	swamp_witch
7	Looseifur	swamp_rabbit
8	Jade Slime	peaks_slime
8	Crystal Frog	peaks_frog
8	Peak Elemental	peaks_elemental
8	Magic Bones	peaks_skull
8	Swift Watcher	peaks_eye
8	Blood Sucker	peaks_mouth
8	Crystal Dagger	peaks_sword
8	Shunzee	peaks_jackal
9	Flame Spawn	mountain_fire
9	Fire Spreader	mountain_moth
9	Obsidian Jelly	mountain_slime
9	Blazing Skull	mountain_skull
9	Erupted Lava	mountain_mist
9	Flame Seeker	mountain_eye
9	Blazing Slasher	mountain_sword
9	Azzmodious	mountain_horned
10	Wonderpot	void_potion
10	Orbious	void_orb
10	Brainmuck	void_skull
10	Sarantis	void_witch
10	Voidrot	void_voidling
10	Skenruppur	void_tentacle
10	Sorbyrous	void_hound
10	Donger	void_dwarf
"""

for key in region_keys:
    final_dict[region_keys[key]] = {}

count = 0
    
for row in data.split('\n'):
    arr = row.split('\t')

    if len(arr) <= 1:
        continue
    
    if count == 8:
        count = 0
    
    region_ind = arr[0]
    name = arr[1]
    id = arr[2]
    
    region = region_keys[str(region_ind)]
    
    final_dict[region][count] = {}
    
    final_dict[region][count]["xp_given"] = "1"
    final_dict[region][count]["food_cost"] = "1"
    final_dict[region][count]["travel_time"] = "1"
    final_dict[region][count]["main_stat"] = "atk_stab"
    
    final_dict[region][count]["abilities"] = {}
    final_dict[region][count]["drops"] = {}
    
    final_dict[region][count]["name"] = name
    final_dict[region][count]["id"] = id
    
    final_dict[region][count]["stats"] = {}
    final_dict[region][count]["stats"]["atk_speed"] = "1"
    final_dict[region][count]["stats"]["atk_crush"] = "1"
    final_dict[region][count]["stats"]["atk_slash"] = "1"
    final_dict[region][count]["stats"]["atk_stab"] = "1"
    final_dict[region][count]["stats"]["def_crush"] = "1"
    final_dict[region][count]["stats"]["def_stab"] = "1"
    final_dict[region][count]["stats"]["def_slash"] = "1"
    final_dict[region][count]["stats"]["dmg_reduc"] = "1"
    final_dict[region][count]["stats"]["health"] = "1"
    final_dict[region][count]["stats"]["max_hit"] = "1"
    final_dict[region][count]["stats"]["min_hit"] = "1"

    count = count + 1

print(final_dict)
# Out:
# {'verdant_valley': {0: {'xp_given': '1', 'food_cost': '1', 'travel_time': '1', 'main_stat': 'atk_stab', 'abilities': {}, 'drops': {}, 'name': 'Farm Chicken', 'id': 'valley_chicken', 'stats': {'atk_speed': '1', 'atk_crush': '1', 'atk_slash': '1', 'atk_stab': '1', 'def_crush': '1', 'def_stab': '1', 'def_slash': '1', 'dmg_reduc': '1', 'health': '1', 'max_hit': '1', 'min_hit': '1'}}, 1: {'xp_given': '1', 'food_cost': '1', 'travel_time': '1', 'main_stat': 'atk_stab', 'abilities': {}, 'drops': {}, 'name': 'Sneaky Rabbit', 'id': 'valley_rabbit', 'stats': {'atk_speed': '1', 'atk_crush': '1', 'atk_slash': '1', 'atk_stab': '1', 'def_crush': '1', 'def_stab': '1', 'def_slash': '1', 'dmg_reduc': '1', 'health': '1', 'max_hit': '1', 'min_hit': '1'}}, 2: {'xp_given': '1', 'food_cost': '1', 'travel_time': '1', 'main_stat': 'atk_stab', 'abilities': {}, 'drops': {}, 'name': 'Crusty Crab', 'id': 'valley_crab', 'stats': {'atk_speed': '1', 'atk_crush': '1', 'atk_slash': '1', 'atk_stab': '1', 'def_crush': 
# ...
