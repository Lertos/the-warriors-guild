# %%
import json


material_amounts_for_gear = {
    'helmet': 3,
    'chestplate': 4,
    'gloves': 2,
    'boots': 1,
    'sword': [2, (2, 1)],
    'dagger': [1, (2, 1)],
    'axe': [4, (4, 3)],
    'gauntlet': [3, (3, 2)],
    'knuckles': [3, (3, 2)],
    'maul': [4, (4, 3)],
    'spear': [3, (3, 2)]
}

#Base armor materials
armor_region_materials = {
    1: 'Cloth',
    2: 'Leather',
    3: 'Hardleather',
    4: 'Dulite',
    5: 'Midite',
    6: 'Shinite',
    7: 'Desite',
    8: 'Lavite',
    9: 'Bonite'
}

#Region types
region_materials = {
    1: 'Stone',
    2: 'Bloodstone',
    3: 'Soulstone',
    4: 'Dulite',
    5: 'Midite',
    6: 'Shinite',
    7: 'Desite',
    8: 'Lavite',
    9: 'Bonite',
    10: 'Twisted'
}

#Primary weapon materials
weapon_primary_region_materials = {
    1: 'Stone',
    2: 'Stone',
    3: 'Stone',
    4: 'Dulite',
    5: 'Midite',
    6: 'Shinite',
    7: 'Desite',
    8: 'Lavite',
    9: 'Bonite',
    10: 'Twisted'
}

#Secondary weapon materials
weapon_second_region_materials = {
    1: 'Stone',
    2: 'Blood Essence',
    3: 'Ectoplasm',
    4: 'Dulite',
    5: 'Midite',
    6: 'Shinite',
    7: 'Light Essence',
    8: 'Fire Essence',
    9: 'Bonite',
    10: 'Void Essence'
}

item_type_to_column = {
    #Armor only has one price per type
    'helmet': 5,
    'chestplate': 7,
    'gloves': 3,
    'boots': 1,
    #First index will be normal price, second will be the exotic price
    'sword': [2, 10],
    'dagger': [0, 10],
    'axe': [8, 13],
    'gauntlet': [4, 11],
    'knuckles': [4, 11],
    'maul': [9, 13],
    'spear': [6, 12]
}


final_dict = {}

times_to_craft = """
1	600	617	634	651	668	685	703	720	737	754	771	788	805	--
2	667	693	720	747	773	800	827	853	880	906	933	960	986	1013
3	850	877	905	933	961	988	1016	1044	1071	1099	1127	1155	1182	1210
4	1042	1070	1099	1127	1156	1184	1213	1242	1270	1299	1327	1356	1384	--
5	1239	1269	1298	1327	1356	1386	1415	1444	1474	1503	1532	1561	1591	1620
6	1443	1473	1502	1532	1562	1592	1622	1651	1681	1711	1741	1770	1800	1830
7	1650	1680	1711	1741	1771	1801	1832	1862	1892	1922	1952	1983	2013	2043
8	1861	1891	1922	1953	1983	2014	2045	2075	2106	2136	2167	2198	2228	2259
9	2074	2105	2136	2167	2198	2229	2260	2291	2322	2353	2384	2415	2446	2477
10	2290	2322	2353	2384	2416	2447	2479	2510	2541	2573	2604	2635	2667	2698
"""

costs_to_craft = """
1	19	26	40	49	68	79	104	118	149	165	203	222	268	291
2	53	73	105	130	170	202	255	291	354	399	471	525	612	675
3	119	163	225	276	351	415	502	572	676	756	880	973	1119	1228
4	214	293	391	482	600	705	847	954	1121	1241	1436	1570	1797	1948
5	340	467	612	757	925	1091	1286	1453	1674	1890	2145	2352	2639	2868
6	502	680	888	1104	1346	1566	1841	2085	2397	2667	2960	3252	3642	3967
yes	sword	7	Desite Sword
yes	sword	7	Elecdesite Sword
	sword	7	Dawnblade
yes	sword	8	Lavite Sword
yes	sword	8	Blazite Sword
	sword	8	Heated Slicer
	sword	8	The Mangler
yes	sword	9	Bonite Sword
yes	sword	9	Guthanos
	sword	9	Piece Maker
	sword	9	Layered Pain
yes	sword	10	Twisted Sword
	sword	10	Mechanical Skewer
	sword	10	The Gardener
	sword	10	Frozen Hell
	sword	10	Blinding Light
	sword	10	Hope Ender
yes	dagger	1	Stone Dagger
yes	dagger	1	Jagged Edge
	dagger	1	Vine Piercer
yes	dagger	2	Bloodstone Dagger
yes	dagger	2	Bloodsoaker
	dagger	2	Ebonblade
yes	dagger	3	Soulstone Dagger
yes	dagger	3	The Stake
	dagger	3	Cube Carver
yes	dagger	4	Dulite Dagger
yes	dagger	4	Dulite Kris
	dagger	4	Blunt Shaver
yes	dagger	5	Midite Dagger
yes	dagger	5	The Blinder
	dagger	5	Frenzy
yes	dagger	6	Shinite Dagger
yes	dagger	6	Solid Sabre
	dagger	6	Royal Carver
yes	dagger	7	Desite Dagger
yes	dagger	7	Elecdesite Dagger
	dagger	7	Fleshshaper
yes	dagger	8	Lavite Dagger
yes	dagger	8	Blazite Dagger
	dagger	8	Lavablade
	dagger	8	Gutstabber
yes	dagger	9	Bonite Dagger
yes	dagger	9	Molten Pain
	dagger	9	Bloodsucker
	dagger	9	Returning Kunai
yes	dagger	10	Twisted Dagger
	dagger	10	The Meat Cleaver
	dagger	10	Fear Eater
	dagger	10	Shadowfall
	dagger	10	Last Rites
	dagger	10	The Grave Filler
yes	gauntlet	1	Stone Gauntlet
yes	gauntlet	1	Needlers
yes	gauntlet	2	Bloodstone Gauntlet
yes	gauntlet	2	Singed Talons
yes	gauntlet	3	Soulstone Gauntlet
yes	gauntlet	3	Twin Fangs
yes	gauntlet	4	Dulite Gauntlet
yes	gauntlet	4	Flesh Openers
yes	gauntlet	5	Midite Gauntlet
yes	gauntlet	5	Nibblers
yes	gauntlet	6	Shinite Gauntlet
yes	gauntlet	6	Slice of Life
yes	gauntlet	7	Desite Gauntlet
yes	gauntlet	7	Elecdesite Gauntlet
	gauntlet	7	The Phoenixes
yes	gauntlet	8	Lavite Gauntlet
yes	gauntlet	8	Blazite Gauntlet
	gauntlet	8	Ruined Saws
yes	gauntlet	9	Bonite Gauntlet
yes	gauntlet	9	Pincers
	gauntlet	9	Soulsuckers
yes	gauntlet	10	Twisted Gauntlet
	gauntlet	10	Dawnsplitters
	gauntlet	10	The Hollowers
yes	axe	1	Stone Axe
yes	axe	1	The Hoe
yes	axe	2	Bloodstone Axe
yes	axe	2	Crazed Chopper
	axe	2	Living Cleaver
yes	axe	3	Soulstone Axe
yes	axe	3	Double Fury
	axe	3	Dundor
yes	axe	4	Dulite Axe
yes	axe	4	Stormedge
	axe	4	The Reaper
yes	axe	5	Midite Axe
yes	axe	5	Soul Reaper
yes	axe	6	Shinite Axe
yes	axe	6	Gutrender
yes	axe	7	Desite Axe
yes	axe	7	Elecdesite Axe
	axe	7	Flameweaver
yes	axe	8	Lavite Axe
yes	axe	8	Blazite Axe
	axe	8	Skeletal Reaver
yes	axe	9	Bonite Axe
yes	axe	9	Painbringer
	axe	9	Bloody Dualblade
yes	axe	10	Twisted Axe
	axe	10	Holy Cross
	axe	10	Hellreacher
	axe	10	Vanquisher
	axe	10	Doomsday
yes	spear	1	Stone Spear
yes	spear	2	Bloodstone Spear
yes	spear	2	Justice
yes	spear	3	Soulstone Spear
yes	spear	3	Witherbrand
yes	spear	4	Dulite Spear
yes	spear	5	Midite Spear
yes	spear	5	Gloompike
yes	spear	6	Shinite Spear
yes	spear	6	Truthseeker
yes	spear	7	Desite Spear
yes	spear	7	Elecdesite Spear
yes	spear	8	Lavite Spear
yes	spear	8	Blazite Spear
yes	spear	9	Bonite Spear
yes	spear	9	Apocalypse
yes	spear	10	Twisted Spear
	spear	10	The Vindicator
	spear	10	The Silent Shovel
yes	maul	1	Stone Maul
yes	maul	1	Giant Smasher
	maul	1	Truth Serum
yes	maul	2	Bloodstone Maul
yes	maul	2	Voice of Reason
	maul	2	Vinethorn
yes	maul	3	Soulstone Maul
yes	maul	3	Mangled Mess
	maul	3	Skullcrusher
yes	maul	4	Dulite Maul
yes	maul	4	Hatred
	maul	4	Tough as Nails
yes	maul	5	Midite Maul
yes	maul	5	Mourning Star
	maul	5	One Hit Wonder
yes	maul	6	Shinite Maul
yes	maul	6	Lightbane
	maul	6	Robocrush
yes	maul	7	Desite Maul
yes	maul	7	Elecdesite Maul
	maul	7	Starsmash
yes	maul	8	Lavite Maul
yes	maul	8	Blazite Maul
	maul	8	Heatbringer
	maul	8	Drain Bamage
yes	maul	9	Bonite Maul
yes	maul	9	Sweet Glory
	maul	9	Necropunch
	maul	9	The Warden
yes	maul	10	Twisted Maul
	maul	10	Ogres Best Friend
	maul	10	Silence Splitter
	maul	10	Satanic Flail
	maul	10	Wall Breaker
	maul	10	Soulkeeper
yes	knuckles	1	Stone Knuckles
yes	knuckles	1	Faceplant
yes	knuckles	2	Bloodstone Knuckles
yes	knuckles	2	Subtle Sting
yes	knuckles	3	Soulstone Knuckles
yes	knuckles	3	The Pounders
yes	knuckles	4	Dulite Knuckles
yes	knuckles	4	Winters Bite
yes	knuckles	5	Midite Knuckles
yes	knuckles	5	Dualism
yes	knuckles	6	Shinite Knuckles
yes	knuckles	6	Dual Knuckles
yes	knuckles	7	Desite Knuckles
yes	knuckles	7	Elecdesite Knuckles
	knuckles	7	Facial Makeover
yes	knuckles	8	Lavite Knuckles
yes	knuckles	8	Blazite Knuckles
	knuckles	8	Flesh Leech
yes	knuckles	9	Bonite Knuckles
yes	knuckles	9	Life Eater
	knuckles	9	Eye Bruisers
yes	knuckles	10	Twisted Knuckles
	knuckles	10	Life Voider
	knuckles	10	Nullfists
"""

for row in list_of_items.split('\n'):
    arr = row.split('\t')

    if len(arr) <= 1:
        continue

    crafted = True
    
    if arr[0] != 'yes':
        crafted = False
    
    if crafted == False:
        continue
    
    #Check if the item is crafted in the workbench; essentially all gear is crafting bench; all else is vendor-specific
    crafted_in_bench = False
    
    if sub_type in ['helmet', 'chestplate', 'gloves', 'boots', 'sword', 'axe', 'dagger', 'maul', 'spear', 'knuckles', 'gauntlet']:
        crafted_in_bench = True
    
    sub_type = arr[1]
    region = int(arr[2])
    name = arr[3]
    
    item_id = name.replace(' ', '_')
    item_id = item_id.lower()

    final_dict[item_id] = {}
    
    #Find buy and sell price based on material, region, and sub type
    sub_type_index = -1
    
    materials = []
    material_amounts = []
    
    #Armor
    if sub_type in ['helmet', 'chestplate', 'gloves', 'boots']:
        sub_type_index = item_type_to_column[sub_type]
        
        materials.append(armor_region_materials[region].lower().replace(' ', '_'))
        material_amounts.append(material_amounts_for_gear[sub_type])
    #Weapons
    else:
        region_material = region_materials[region].lower()
        material_substring = name[0:len(region_material)].lower()

        if region_material in material_substring:
            sub_type_index = item_type_to_column[sub_type][0]
            
            materials.append(weapon_primary_region_materials[region].lower().replace(' ', '_'))
            material_amounts.append(material_amounts_for_gear[sub_type][0])
        else:
            sub_type_index = item_type_to_column[sub_type][1]
            
            materials.append(weapon_primary_region_materials[region].lower().replace(' ', '_'))
            material_amounts.append(material_amounts_for_gear[sub_type][1][0])
            
            materials.append(weapon_second_region_materials[region].lower().replace(' ', '_'))
            material_amounts.append(material_amounts_for_gear[sub_type][1][1])
    
    craft_time = int(times_to_craft.split('\n')[region].split('\t')[sub_type_index])
    craft_cost = int(costs_to_craft.split('\n')[region].split('\t')[sub_type_index])
    craft_xp = int(xp_for_crafting.split('\n')[region].split('\t')[sub_type_index])
    
    
    final_dict[item_id]['secs_to_craft'] = str(craft_time)
    final_dict[item_id]['gold_to_craft'] = str(craft_cost)
    final_dict[item_id]['xp_from_craft'] = str(craft_xp)
    final_dict[item_id]['crafted_in_bench'] = crafted_in_bench
    
    final_dict[item_id]['materials'] = {}
    
    for index in range(0, len(materials)):
        final_dict[item_id]['materials'][materials[index]] = str(material_amounts[index])


print(json.dumps(final_dict))
# Out:
# {"cloth_helmet": {"secs_to_craft": "668", "gold_to_craft": "68", "xp_from_craft": "1124", "crafted_in_bench": true, "materials": {"cloth": "3"}}, "cloth_chestplate": {"secs_to_craft": "703", "gold_to_craft": "104", "xp_from_craft": "1512", "crafted_in_bench": true, "materials": {"cloth": "4"}}, "cloth_gloves": {"secs_to_craft": "634", "gold_to_craft": "40", "xp_from_craft": "760", "crafted_in_bench": true, "materials": {"cloth": "2"}}, "cloth_boots": {"secs_to_craft": "600", "gold_to_craft": "19", "xp_from_craft": "430", "crafted_in_bench": true, "materials": {"cloth": "1"}}, "leather_helmet": {"secs_to_craft": "773", "gold_to_craft": "170", "xp_from_craft": "2100", "crafted_in_bench": true, "materials": {"leather": "3"}}, "leather_chestplate": {"secs_to_craft": "827", "gold_to_craft": "255", "xp_from_craft": "2889", "crafted_in_bench": true, "materials": {"leather": "4"}}, "leather_gloves": {"secs_to_craft": "720", "gold_to_craft": "105", "xp_from_craft": "1400", "crafted_in_bench":
# ...
